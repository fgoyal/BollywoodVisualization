# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('bollywood_kaggle.csv')

# %%
# drop unneeded columns
data = data.drop('Genre', axis=1)
# data = data.drop('Title', axis=1)

# %%
# create new column with the directors and cast combined, properly formatted
data['Director'] = data['Director'].str.replace(' ',',')
data['People'] = data['Director'] + "," + data["Cast"]
data['People'] = data['People'].str.replace('(','')
data['People'] = data['People'].str.replace(')','')
data['People'] = data['People'].str.lower()

# %%
# drop unneeded columns
data = data.drop('Cast', axis=1)
data = data.drop('Director', axis=1)

# %%
# create new dataframe 
unsplit = pd.DataFrame.copy(data, deep=True)
unsplit['People'] = unsplit['People'].str.replace(',',' ')

# %%
# split People column by comma
data = data.join(data.People.str.split(',', expand=True))
data = data.drop('People', axis=1)

# %%
data = data.iloc[::-1]

# %%
# search for amitabh bachchan
names = ["amitabh", "bachchan"]
filtered = unsplit
filtered
for name in names:
    has_name = filtered['People'].str.contains(name)
    filtered = filtered[has_name]
    

filtered

# filtered
# plt.figure(figsize=(15,5))

# # create year range
# years = pd.Series(range(1920,2018))

# # get frequency counts and map to years
# frequency = filtered['Year'].value_counts()
# frequency = frequency.reindex(years, fill_value=0)

# # create graph
# # frequency.sort_index(axis=0, level=None, ascending=True, inplace=True, sort_remaining=True)
# ax = frequency.plot(kind='line', x='Year', y='Appearances')
# ax.set_xlabel("Year")
# ax.set_ylabel("Amitabh Bachchan Appearances")
# Out:
#       Year                                              Title  \
# 0     1920                     Balika Badhu a.k.a. Baby Bride
# 1     1920                   Daksha Yagna a.k.a. Sati Parvati
# 2     1920          Jalandhar Vrinda a.k.a. Sati Tulsi Vrinda
# 3     1920          Kansa Vadha a.k.a. End Of The Tyrant King
# 4     1920  Katorabhar Khoon a.k.a.The Stinger Stung a.k.a...
# 5     1920          Krishna Sudama a.k.a. Shri Krishna Sudama
# 6     1920                                         Lava Kusha
# 7     1920                                        Mahabharata
# 8     1920                                       Mrichhakatik
# 9     1920                                    Narasinha Avtar
# 10    1920                                      Narsinh Mehta
# 11    1920                                          Ram Janma
# 12    1920                                       Rama Or Maya
# 13    1920                                         Sairandhri
# 14    1920                                         Shakuntala
# 15    1920                                         Shakuntala
# 16    1920                                 Shri Krishna Leela
# 17    1920                                    Shri Rama Janma
# 18    1920              Sita Swayamwar a.k.a. Sita's Marriage
# 19    1920         The Enchanted Pills a.k.a. Vichitra Gutika
# 20    1920                                     Vikram Urvashi
# 21    1921                                             Behula
# 22    1921                   Belgian Emperor's Visit To India
# 23    1921                                       Bhakta Vidur
# 24    1921               Bilet Pherat a.k.a. England Returned
# 25    1921                                        Chandrahasa
# 26    1921                                   Dabbur Kelenkari
# 27    1921         Dhruva Charitra a.k.a. The Story Of Dhruva
# 28    1921                    King Gopichand a.k.a. Gopichand
# 29    1921                                    Govardhan Dhari
# ...    ...                                                ...
# 9450  2017                                             Deepak
# 9451  2017                                               Chef
# 9452  2017                           Babu Ji Ek Ticket Bambai
# 9453  2017                           Mein Terrorist Nahi Hoon
# 9454  2017                                     Ranchi Diaries
# 9455  2017                                   Secret Superstar
# 9456  2017                                      Golmaal Again
# 9457  2017                                        Jia aur Jia
# 9458  2017                                               Rukh
# 9459  2017                                            Ittefaq
# 9460  2017                                The House Next Door
# 9461  2017                                             Ribbon
# 9462  2017                            Shaadi Mein Zaroor Aana
# 9463  2017                                Qarib Qarib Singlle
# 9464  2017                                         The Window
# 9465  2017                                            Aksar 2
# 9466  2017                                          Panchlait
# 9467  2017                                       Tumhari Sulu
